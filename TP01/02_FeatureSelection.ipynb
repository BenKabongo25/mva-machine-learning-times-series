# %% [markdown]
# **Machine Learning for Time Series (Master MVA)**
#
# - TP1, Thursday 18<sup>th</sup> October 2023
# - [Link to the class material.](http://www.laurentoudre.fr/ast.html)
#
# **Ben Kabongo B.**

# %% [markdown]
# # Introduction
#
# In this tutorial, we illustrate the following concepts:
#
# - feature extraction on time series
# - feature selection

# %% [markdown]
# ## Setup
#
# **Imports**

# %%
from itertools import tee
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from loadmydata.load_uea_ucr import load_uea_ucr_data
from numpy.fft import rfft, rfftfreq
from scipy.cluster import hierarchy
from scipy.signal import argrelmax, stft
from scipy.spatial.distance import pdist, squareform
from scipy.stats import f_oneway, spearmanr, kurtosis, scoreatpercentile
from sklearn.decomposition import PCA
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, make_scorer
from sklearn.neighbors import KNeighborsClassifier
from sklearn.feature_selection import SequentialFeatureSelector
from statsmodels.tsa.stattools import acf

# %% [markdown]
# **Utility functions**

# %%
def pairwise(iterable):
    "s -> (s0,s1), (s1,s2), (s2, s3), ..."
    a, b = tee(iterable)
    next(b, None)
    return zip(a, b)

# %%
def get_largest_local_max(signal1D: np.ndarray, order: int = 1):
    """Return the largest local max and the associated index in a tuple.

    This function uses `order` points on each side to use for the comparison.
    """
    all_local_max_indexes = argrelmax(signal1D, order=order)[0]
    all_local_max = np.take(signal1D, all_local_max_indexes)
    largest_local_max_index = all_local_max_indexes[all_local_max.argsort()[-1]]

    return signal1D[largest_local_max_index], largest_local_max_index

# %%
def fig_ax(figsize=(15, 5)):
    return plt.subplots(figsize=figsize)

# %% [markdown]
# ## Data

# %%
BASE_PATH = "./data/"
dataset_name = "BinaryHeartbeat"
#data = load_uea_ucr_data(dataset_name)
#print(data.description)
X_train = np.loadtxt(BASE_PATH + "BinaryHeartbeat.csv").reshape((204, 18530, 1))
print(X_train.shape)
# Out:
# (204, 18530, 1)

# %%
y_train = np.loadtxt(BASE_PATH + "BinaryHeartbeat_label.txt", dtype=str)
y_train.shape
# Out:
# (204,)

# %%
# Sampling frequency
FREQUENCY = 2000  # Hz

# %% [markdown]
# Choose a signal from the data set.

# %%
ind = 43
signal = X_train[ind].flatten()
label = y_train[ind]
n_samples = signal.shape[0]
print(label)
# Out:
# Abnormal

# %%
fig, ax = fig_ax()
tt = np.arange(n_samples) / FREQUENCY
ax.plot(tt, signal)
_ = ax.set_xlim(0, n_samples / FREQUENCY)

# %% [markdown]
# Compute the spectrogram

# %%
f, t, Zxx = stft(signal, fs=FREQUENCY, nperseg=1000, noverlap=800)

# %%
fig, ax = fig_ax()
ax.pcolormesh(t, f, np.abs(Zxx), vmin=0, shading="gouraud")
ax.set_xlabel("Time (s)")
_ = ax.set_ylabel("Frequency (Hz)")

# %% [markdown]
# <div class="alert alert-success" role="alert">
#     <p><b>Question</b></p>
#     <p>Replot the same spectrogram as above, but zoom on the interesting frequencies (set <tt>cut_off_freq</tt> in the following cell).</p>
#     <ul>
#         <li>What are the repeated patterns? What is the frequency of interest (approximately)?</li>
#         <li>What happens when you increase the number of samples per windows?</li>
#         <li>What happens when you increase the overlap between windows?</li>
#     </ul>
# </div>

# %%
# Cut-off frequency
cut_off_freq = 200  # Hz

# %%
fig, ax = fig_ax()

f, t, Zxx = stft(signal, fs=FREQUENCY, nperseg=1024, noverlap=512)

keep_mask = f < cut_off_freq

ax.pcolormesh(
    t, f[keep_mask], np.abs(Zxx[keep_mask]), vmin=0, shading="gouraud"
)
ax.set_xlabel("Time (s)")
_ = ax.set_ylabel("Frequency (Hz)")

# %% [markdown]
# # Feature extraction

# %% [markdown]
# ## Statistical features

# %% [markdown]
# ### Moments and percentiles

# %%
def get_distribution_features(signal: np.ndarray) -> dict:
    res_dict = dict()
    res_dict["mean"] = signal.mean()
    res_dict["std"] = signal.std()
    res_dict["min"] = signal.min()
    res_dict["max"] = signal.max()
    return res_dict

# %%
get_distribution_features(signal)
# Out:
# {'mean': -0.0001340632515893146,
#  'std': 0.016301577891802192,
#  'min': -0.2733459,
#  'max': 0.1954651}

# %% [markdown]
# <div class="alert alert-success" role="alert">
#     <p><b>Question</b></p>
#     <p> Rewrite in the following cell, the function <tt>get_distribution_features(signal)->dict</tt> so that is also computes the kurtosis, the skew (available in the <tt>scipy.stats</tt> module) and the 25%, 50% and 75% percentiles.</p>
# </div>

# %%
def get_distribution_features(signal: np.ndarray) -> dict:
    res_dict = dict()
    res_dict["mean"] = signal.mean()
    res_dict["std"] = signal.std()
    res_dict["min"] = signal.min()
    res_dict["max"] = signal.max()
    res_dict["kurtosis"] = kurtosis(signal)
    res_dict["25%"] = scoreatpercentile(signal, 25)
    res_dict["50%"] = scoreatpercentile(signal, 50)
    res_dict["75%"] = scoreatpercentile(signal, 75)
    return res_dict

# %%
get_distribution_features(signal)
# Out:
# {'mean': -0.0001340632515893146,
#  'std': 0.016301577891802192,
#  'min': -0.2733459,
#  'max': 0.1954651,
#  'kurtosis': 11.667627130585604,
#  '25%': -0.008209229,
#  '50%': -9.155273e-05,
#  '75%': 0.007904053}

# %% [markdown]
# ### Autocorrelation

# %% [markdown]
# For a signal $x\in\mathbb{R}^N$ with $N$ samples, the autocorrelation with lag $m$ is defined as follows: TYPO IN THE SUM
#
# $$
# \hat{\gamma}[m] := \frac{1}{N-|m|} \sum_{n=0}^{N-1} x[n]x[n+m].
# $$
#
# Note that if the signal $x$ is periodic, then the autocorrelation is also periodic with same period.

# %% [markdown]
# Let us plot the autocorrelation of a sound signal.

# %%
fig, ax = fig_ax()
ax.plot(acf(signal, nlags=200, fft=True), ".-")
ax.axhline(0, ls="--", color="k")
plt.show()

# %% [markdown]
# <div class="alert alert-success" role="alert">
#     <p><b>Question</b></p>
#     <p>We would like to also compute the maximum autocorrelation value and the associated lag in Hz (a local maximum that is not 0). Explain how you can convert a lag expressed in number of samples to a lag expressed in Hz.</p>
# </div>

# %% [markdown]
# `shift / frequency -> periode (s)`

# %% [markdown]
# Compute the autocorrelation features.

# %%
def get_autocorr_features(signal: np.ndarray, n_lags: int = 200) -> dict:
    auto_corr = acf(signal, nlags=n_lags, fft=True)
    res_dict = dict()
    for lag, auto_corr_value in enumerate(auto_corr):
        res_dict[f"autocorrelation_{lag}_lag"] = auto_corr_value

    local_max, local_argmax = get_largest_local_max(
        auto_corr, order=20
    )  #######
    res_dict["lag_max_autocorrelation_Hz"] = FREQUENCY / local_argmax
    res_dict["max_autocorrelation"] = local_max

    return res_dict

# %%
get_autocorr_features(signal, n_lags=100)
# Out:
# {'autocorrelation_0_lag': 1.0,
#  'autocorrelation_1_lag': 0.7400314104217104,
#  'autocorrelation_2_lag': 0.7508286942334464,
#  'autocorrelation_3_lag': 0.8430264536926754,
#  'autocorrelation_4_lag': 0.6855270570977194,
#  'autocorrelation_5_lag': 0.6919429887382064,
#  'autocorrelation_6_lag': 0.6289539914001856,
#  'autocorrelation_7_lag': 0.5731971033063795,
#  'autocorrelation_8_lag': 0.5105704270738207,
#  'autocorrelation_9_lag': 0.47370124256854734,
#  'autocorrelation_10_lag': 0.3907372394639896,
#  'autocorrelation_11_lag': 0.31861881884425425,
#  'autocorrelation_12_lag': 0.2944045491101345,
#  'autocorrelation_13_lag': 0.20245569730806806,
#  'autocorrelation_14_lag': 0.15653210788996522,
#  'autocorrelation_15_lag': 0.10230186705237922,
#  'autocorrelation_16_lag': 0.05523473059019857,
#  'autocorrelation_17_lag': -0.0018165102662364401,
#  'autocorrelation_18_lag': -0.04392150205043145,
#  'autocorrelation_19_lag': -0.07121117832687782,
#  'autocorrelation_20_lag': -0.12202539586849392,
#  'autocorrelation_21_lag': -0.13993816525490738,
#  'autocorrelation_22_lag': -0.16726988993304556,
#  'autocorrelation_23_lag': -0.19021624691197533,
#  'autocorrelation_24_lag': -0.1984153398470942,
#  'autocorrelation_25_lag': -0.21452167191782834,
#  'autocorrelation_26_lag': -0.22724887101716126,
#  'autocorrelation_27_lag': -0.2218431757160123,
#  'autocorrelation_28_lag': -0.22926684620799634,
#  'autocorrelation_29_lag': -0.23824311200500933,
#  'autocorrelation_30_lag': -0.2216149635117706,
#  'autocorrelation_31_lag': -0.2289375782525888,
#  'autocorrelation_32_lag': -0.22555541687045683,
#  'autocorrelation_33_lag': -0.2143666368241369,
#  'autocorrelation_34_lag': -0.21637263735674964,
#  'autocorrelation_35_lag': -0.2035498300306589,
#  'autocorrelation_36_lag': -0.20401738638571393,
#  'autocorrelation_37_lag': -0.19780861652132783,
#  'autocorrelation_38_lag': -0.18420736662849196,
#  'autocorrelation_39_lag': -0.18338759362674673,
#  'autocorrelation_40_lag': -0.18219404405843756,
#  'autocorrelation_41_lag': -0.16806093656320364,
#  'autocorrelation_42_lag': -0.15983807916890402,
#  'autocorrelation_43_lag': -0.163718204537442,
#  'autocorrelation_44_lag': -0.14911120205836925,
#  'autocorrelation_45_lag': -0.15028307445062747,
#  'autocorrelation_46_lag': -0.13662891147046402,
#  'autocorrelation_47_lag': -0.13186215280452582,
#  'autocorrelation_48_lag': -0.1444136709524033,
#  'autocorrelation_49_lag': -0.10692787287852255,
#  'autocorrelation_50_lag': -0.12012339123448272,
#  'autocorrelation_51_lag': -0.12462640888587229,
#  'autocorrelation_52_lag': -0.09057131443967967,
#  'autocorrelation_53_lag': -0.102985171828117,
#  'autocorrelation_54_lag': -0.09752256201020129,
#  'autocorrelation_55_lag': -0.08723529309817428,
#  'autocorrelation_56_lag': -0.08270644724395064,
#  'autocorrelation_57_lag': -0.07569813449555034,
#  'autocorrelation_58_lag': -0.07823294297333111,
#  'autocorrelation_59_lag': -0.06411924247273815,
#  'autocorrelation_60_lag': -0.05501068669616673,
#  'autocorrelation_61_lag': -0.07380666715728629,
#  'autocorrelation_62_lag': -0.04988393915309971,
#  'autocorrelation_63_lag': -0.03877906892715857,
#  'autocorrelation_64_lag': -0.06978685897754196,
#  'autocorrelation_65_lag': -0.038840237501344216,
#  'autocorrelation_66_lag': -0.04698569712150275,
#  'autocorrelation_67_lag': -0.06585927058172064,
#  'autocorrelation_68_lag': -0.03634789214622298,
#  'autocorrelation_69_lag': -0.05641929233605791,
#  'autocorrelation_70_lag': -0.0698351198067127,
#  'autocorrelation_71_lag': -0.05741565851614553,
#  'autocorrelation_72_lag': -0.06727720302011587,
#  'autocorrelation_73_lag': -0.07723550087642249,
#  'autocorrelation_74_lag': -0.08515227463265095,
#  'autocorrelation_75_lag': -0.08710792050193225,
#  'autocorrelation_76_lag': -0.08561191290679,
#  'autocorrelation_77_lag': -0.11089562957876391,
#  'autocorrelation_78_lag': -0.10739854236148794,
#  'autocorrelation_79_lag': -0.10090906825309832,
#  'autocorrelation_80_lag': -0.1236776316359469,
#  'autocorrelation_81_lag': -0.12363411553355771,
#  'autocorrelation_82_lag': -0.1227346906800465,
#  'autocorrelation_83_lag': -0.12611627250711982,
#  'autocorrelation_84_lag': -0.13327260972512686,
#  'autocorrelation_85_lag': -0.12745172921158326,
#  'autocorrelation_86_lag': -0.12677019585190927,
#  'autocorrelation_87_lag': -0.13042581966880396,
#  'autocorrelation_88_lag': -0.11848623271379703,
#  'autocorrelation_89_lag': -0.12539307100996697,
#  'autocorrelation_90_lag': -0.10882137726540307,
#  'autocorrelation_91_lag': -0.10558762965249631,
#  'autocorrelation_92_lag': -0.11218718765519956,
#  'autocorrelation_93_lag': -0.08082360642020354,
#  'autocorrelation_94_lag': -0.0887765071849218,
#  'autocorrelation_95_lag': -0.07814980393197297,
#  'autocorrelation_96_lag': -0.0592317083548012,
#  'autocorrelation_97_lag': -0.06415508991463753,
#  'autocorrelation_98_lag': -0.03932576682453098,
#  'autocorrelation_99_lag': -0.04178064805312231,
#  'autocorrelation_100_lag': -0.02795193071373124,
#  'lag_max_autocorrelation_Hz': 29.41176470588235,
#  'max_autocorrelation': -0.03634789214622298}

# %% [markdown]
# ## Spectral features

# %% [markdown]
# Plot the Fourier coefficients of a signal (y=absolute value, x=frequency) using `rfft()` and `rfftfreq()`.

# %%
fourier = abs(rfft(signal)) ** 2
freqs = rfftfreq(n=n_samples, d=1.0 / FREQUENCY)

fig, ax = fig_ax()
ax.plot(freqs, fourier)
ax.set_xlabel("Frequency (Hz)")
_ = ax.set_ylabel("Fourier coefficient")

# %% [markdown]
# Compute the spectral features.

# %%
def get_fourier_features(signal: np.ndarray, n_bins: int = 100) -> dict:
    """The signal is assumed to be centered and scaled to unit variance."""
    n_samples = signal.shape[0]
    fourier = abs(rfft(signal))
    freqs = rfftfreq(n=n_samples, d=1.0 / FREQUENCY)
    res_dict = dict()

    freq_bins = np.linspace(0, FREQUENCY / 2, n_bins + 1)
    for f_min, f_max in pairwise(freq_bins):
        keep = (f_min <= freqs) & (freqs < f_max)
        res_dict[f"fourier_{f_min:.0f}-{f_max:.0f}_Hz"] = np.log(
            np.sum(fourier[keep] ** 2)
        )
    return res_dict

# %%
get_fourier_features(signal, n_bins=10)
# Out:
# {'fourier_0-100_Hz': 10.518485052224639,
#  'fourier_100-200_Hz': 6.538484756941989,
#  'fourier_200-300_Hz': 5.405330986721309,
#  'fourier_300-400_Hz': 5.2045089641871325,
#  'fourier_400-500_Hz': 6.47667075300163,
#  'fourier_500-600_Hz': 6.962667660990334,
#  'fourier_600-700_Hz': 7.784419285662661,
#  'fourier_700-800_Hz': 7.559518158203596,
#  'fourier_800-900_Hz': 7.290768510598517,
#  'fourier_900-1000_Hz': 3.8087977893623863}

# %% [markdown]
# <div class="alert alert-success" role="alert">
#     <p><b>Question</b></p>
#     <p>The frequency features are not scaled. If the signal is normalized, do we need to?</p>
# </div>

# %% [markdown]
# <div class="alert alert-success" role="alert">
#     <p><b>Question</b></p>
#     <p> We have used regularly spaced frequency bins. What would be a better approach? </p>
#
# </div>

# %% [markdown]
# ## Concatenate all features

# %% [markdown]
# In the following cell, we write a function `get_features(signal: np.ndarray) -> dict` that computes all features from above.

# %%
def get_features(signal: np.ndarray) -> dict:
    res_dict = dict()

    # stats
    res_dict.update(get_distribution_features(signal))

    # spectral
    signal -= signal.mean()
    signal /= signal.std()
    res_dict.update(get_fourier_features(signal, n_bins=50))

    # autocorrelation
    res_dict.update(get_autocorr_features(signal, n_lags=200))

    return res_dict

# %%
get_features(signal)
# Out:
# {'mean': -0.0001340632515893146,
#  'std': 0.016301577891802192,
#  'min': -0.2733459,
#  'max': 0.1954651,
#  'kurtosis': 11.667627130585604,
#  'autocorrelation_11_lag': 0.31861881884425414,
#  'autocorrelation_12_lag': 0.29440454911013453,
#  'autocorrelation_13_lag': 0.20245569730806806,
#  'autocorrelation_14_lag': 0.15653210788996524,
#  'autocorrelation_15_lag': 0.1023018670523792,
#  'autocorrelation_16_lag': 0.05523473059019855,
#  'autocorrelation_17_lag': -0.0018165102662364345,
#  'autocorrelation_18_lag': -0.04392150205043145,
#  'autocorrelation_19_lag': -0.0712111783268778,
#  'autocorrelation_20_lag': -0.12202539586849392,
#  'autocorrelation_21_lag': -0.13993816525490743,
#  'autocorrelation_22_lag': -0.16726988993304556,
#  'autocorrelation_23_lag': -0.19021624691197533,
#  'autocorrelation_24_lag': -0.19841533984709414,
#  'autocorrelation_25_lag': -0.21452167191782842,
#  'autocorrelation_26_lag': -0.22724887101716124,
#  'autocorrelation_27_lag': -0.22184317571601228,
#  'autocorrelation_28_lag': -0.22926684620799628,
#  'autocorrelation_29_lag': -0.23824311200500928,
#  'autocorrelation_30_lag': -0.2216149635117705,
#  'autocorrelation_31_lag': -0.2289375782525888,
#  'autocorrelation_32_lag': -0.22555541687045685,
#  'autocorrelation_33_lag': -0.2143666368241369,
#  'autocorrelation_34_lag': -0.21637263735674958,
#  'autocorrelation_35_lag': -0.2035498300306589,
#  'autocorrelation_36_lag': -0.20401738638571396,
#  'autocorrelation_37_lag': -0.19780861652132778,
#  'autocorrelation_38_lag': -0.18420736662849196,
#  'autocorrelation_39_lag': -0.18338759362674664,
#  'autocorrelation_40_lag': -0.18219404405843756,
#  'autocorrelation_41_lag': -0.16806093656320362,
#  'autocorrelation_42_lag': -0.15983807916890397,
#  'autocorrelation_43_lag': -0.16371820453744199,
#  'autocorrelation_44_lag': -0.14911120205836925,
#  'autocorrelation_45_lag': -0.1502830744506275,
#  'autocorrelation_46_lag': -0.13662891147046402,
#  'autocorrelation_47_lag': -0.13186215280452576,
#  'autocorrelation_48_lag': -0.1444136709524033,
#  'autocorrelation_49_lag': -0.10692787287852254,
#  'autocorrelation_50_lag': -0.12012339123448271,
#  'autocorrelation_51_lag': -0.12462640888587229,
#  'autocorrelation_52_lag': -0.09057131443967965,
#  'autocorrelation_53_lag': -0.10298517182811702,
#  'autocorrelation_54_lag': -0.09752256201020129,
#  'autocorrelation_55_lag': -0.08723529309817425,
#  'autocorrelation_56_lag': -0.08270644724395061,
#  'autocorrelation_57_lag': -0.07569813449555035,
#  'autocorrelation_58_lag': -0.0782329429733311,
#  'autocorrelation_59_lag': -0.06411924247273816,
#  'autocorrelation_60_lag': -0.05501068669616672,
#  'autocorrelation_61_lag': -0.0738066671572863,
#  'autocorrelation_62_lag': -0.04988393915309971,
#  'autocorrelation_63_lag': -0.03877906892715857,
#  'autocorrelation_64_lag': -0.06978685897754194,
#  'autocorrelation_65_lag': -0.0388402375013442,
#  'autocorrelation_66_lag': -0.04698569712150277,
#  'autocorrelation_67_lag': -0.06585927058172064,
#  'autocorrelation_68_lag': -0.03634789214622298,
#  'autocorrelation_69_lag': -0.05641929233605792,
#  'autocorrelation_70_lag': -0.06983511980671268,
#  'autocorrelation_189_lag': -0.035445355904453295,
#  'autocorrelation_190_lag': -0.022262262904025026,
#  'autocorrelation_191_lag': -0.029664460495995696,
#  'autocorrelation_192_lag': -0.03846228062683692,
#  'autocorrelation_193_lag': -0.024359019295434357,
#  'autocorrelation_194_lag': -0.028820865551004726,
#  'autocorrelation_195_lag': -0.029738104869489294,
#  'autocorrelation_196_lag': -0.03144396804129761,
#  'autocorrelation_197_lag': -0.029521063923516846,
#  'autocorrelation_198_lag': -0.020026610749727006,
#  'autocorrelation_199_lag': -0.03433583444476905,
#  'autocorrelation_200_lag': -0.022720914771129867,
#  'lag_max_autocorrelation_Hz': 13.071895424836601,
#  'max_autocorrelation': 0.10313069443408876}

# %% [markdown]
# Compute all features over the data set.

# %%
all_features = pd.DataFrame(
    [get_features(signal.flatten()) for signal in X_train]
)

# %%
all_features.head()
# Out:
#        mean       std       min       max   kurtosis       25%       50%  \
# 0 -0.000044  0.053476 -0.325073  0.291504   4.395775 -0.027130 -0.000610
# 1 -0.000026  0.021232 -0.109467  0.139496   4.207598 -0.011505 -0.000244
# 2 -0.000069  0.034245 -0.253387  0.291596  22.093219 -0.007721 -0.000031
# 3 -0.000026  0.075533 -0.440369  0.644653  15.069250 -0.020012 -0.000275
# 4 -0.000021  0.126608 -1.000000  0.999969  20.218365 -0.017639  0.000275
#
#         75%  fourier_0-20_Hz  fourier_20-40_Hz  ...  autocorrelation_193_lag  \
# 0  0.025116        17.425511         18.089893  ...                -0.013568
# 1  0.010864        17.947738         17.998736  ...                 0.147982
# 2  0.007477        15.761979         17.992996  ...                 0.007707
# 3  0.018646        15.773631         18.058406  ...                 0.003933
# 4  0.016685        15.738893         18.259682  ...                 0.025114
#
#    autocorrelation_194_lag  autocorrelation_195_lag  autocorrelation_196_lag  \
# 0                -0.010462                -0.007693                -0.005201
# 1                 0.143621                 0.139093                 0.134445
# 2                 0.006197                 0.004491                 0.002655
# 3                 0.008041                 0.011920                 0.015518
# 4                 0.024158                 0.023134                 0.022036
#
#    autocorrelation_197_lag  autocorrelation_198_lag  autocorrelation_199_lag  \
# 0                -0.002915                -0.000772                 0.001283
# 1                 0.129681                 0.124822                 0.119951
# 2                 0.000759                -0.001193                -0.003117
# 3                 0.018804                 0.021765                 0.024399
# 4                 0.020845                 0.019556                 0.018152
#
#    autocorrelation_200_lag  lag_max_autocorrelation_Hz  max_autocorrelation
# 0                 0.003267                   20.000000             0.136663
# 1                 0.115106                   10.869565             0.169397
# 2                -0.005015                   40.816327             0.113092
# 3                 0.026711                   30.769231             0.159935
# 4                 0.016617                   37.037037             0.283012
#
# [5 rows x 261 columns]

# %% [markdown]
# <div class="alert alert-success" role="alert">
#     <p><b>Question</b></p>
#     <p> How many features do we have in the end?</p>
# </div>

# %%
all_features.shape
# Out:
# (204, 261)

# %% [markdown]
# # Feature selection

# %% [markdown]
# ## Unsupervised selection

# %% [markdown]
# ### Sanity checks

# %% [markdown]
# #### Low variance threshold

# %%
fig, ax = fig_ax(figsize=(20, 5))
all_features.std().sort_values().plot(ax=ax)

# change the height of the horizontal line here
ax.axhline(0.01, ls="--", color="k")

# %% [markdown]
# <div class="alert alert-success" role="alert">
#     <p><b>Question</b></p>
#     <p> Choose a variance threshold (name it <tt>variance_threshold</tt>).</p>
# </div>

# %%
variance_threshold = 0.5

# %% [markdown]
# Be careful when dropping low variance features, they might still be informative. Quickly check that it makes sense to drop them.

# %%
low_variance_features = all_features.std() < variance_threshold
low_variance_features = low_variance_features[
    low_variance_features
].index.to_numpy()
print(f"There are {len(low_variance_features)} features to drop.")
print(low_variance_features)
# Out:
# There are 211 features to drop.
# ['mean' 'std' 'min' 'max' '25%' '50%' '75%' 'fourier_20-40_Hz'
#  'fourier_40-60_Hz' 'autocorrelation_0_lag' 'autocorrelation_1_lag'
#  'autocorrelation_2_lag' 'autocorrelation_3_lag' 'autocorrelation_4_lag'
#  'autocorrelation_5_lag' 'autocorrelation_6_lag' 'autocorrelation_7_lag'
#  'autocorrelation_8_lag' 'autocorrelation_9_lag' 'autocorrelation_10_lag'
#  'autocorrelation_11_lag' 'autocorrelation_12_lag'
#  'autocorrelation_13_lag' 'autocorrelation_14_lag'
#  'autocorrelation_15_lag' 'autocorrelation_16_lag'
#  'autocorrelation_17_lag' 'autocorrelation_18_lag'
#  'autocorrelation_19_lag' 'autocorrelation_20_lag'
#  'autocorrelation_21_lag' 'autocorrelation_22_lag'
#  'autocorrelation_23_lag' 'autocorrelation_24_lag'
#  'autocorrelation_25_lag' 'autocorrelation_26_lag'
#  'autocorrelation_27_lag' 'autocorrelation_28_lag'
#  'autocorrelation_29_lag' 'autocorrelation_30_lag'
#  'autocorrelation_31_lag' 'autocorrelation_32_lag'
#  'autocorrelation_33_lag' 'autocorrelation_34_lag'
#  'autocorrelation_35_lag' 'autocorrelation_36_lag'
#  'autocorrelation_37_lag' 'autocorrelation_38_lag'
#  'autocorrelation_39_lag' 'autocorrelation_40_lag'
#  'autocorrelation_41_lag' 'autocorrelation_42_lag'
#  'autocorrelation_43_lag' 'autocorrelation_44_lag'
#  'autocorrelation_45_lag' 'autocorrelation_46_lag'
#  'autocorrelation_47_lag' 'autocorrelation_48_lag'
#  'autocorrelation_49_lag' 'autocorrelation_50_lag'
#  'autocorrelation_51_lag' 'autocorrelation_52_lag'
#  'autocorrelation_53_lag' 'autocorrelation_54_lag'
#  'autocorrelation_55_lag' 'autocorrelation_56_lag'
#  'autocorrelation_57_lag' 'autocorrelation_58_lag'
#  'autocorrelation_59_lag' 'autocorrelation_60_lag'
#  'autocorrelation_61_lag' 'autocorrelation_62_lag'
#  'autocorrelation_63_lag' 'autocorrelation_64_lag'
#  'autocorrelation_65_lag' 'autocorrelation_66_lag'
#  'autocorrelation_67_lag' 'autocorrelation_68_lag'
#  'autocorrelation_69_lag' 'autocorrelation_70_lag'
#  'autocorrelation_71_lag' 'autocorrelation_72_lag'
#  'autocorrelation_73_lag' 'autocorrelation_74_lag'
#  'autocorrelation_75_lag' 'autocorrelation_76_lag'
#  'autocorrelation_77_lag' 'autocorrelation_78_lag'
#  'autocorrelation_79_lag' 'autocorrelation_80_lag'
#  'autocorrelation_81_lag' 'autocorrelation_82_lag'
#  'autocorrelation_83_lag' 'autocorrelation_84_lag'
#  'autocorrelation_85_lag' 'autocorrelation_86_lag'
#  'autocorrelation_87_lag' 'autocorrelation_88_lag'
#  'autocorrelation_89_lag' 'autocorrelation_90_lag'
#  'autocorrelation_91_lag' 'autocorrelation_92_lag'
#  'autocorrelation_93_lag' 'autocorrelation_94_lag'
#  'autocorrelation_95_lag' 'autocorrelation_96_lag'
#  'autocorrelation_97_lag' 'autocorrelation_98_lag'
#  'autocorrelation_99_lag' 'autocorrelation_100_lag'
#  'autocorrelation_101_lag' 'autocorrelation_102_lag'
#  'autocorrelation_103_lag' 'autocorrelation_104_lag'
#  'autocorrelation_105_lag' 'autocorrelation_106_lag'
#  'autocorrelation_107_lag' 'autocorrelation_108_lag'
#  'autocorrelation_109_lag' 'autocorrelation_110_lag'
#  'autocorrelation_111_lag' 'autocorrelation_112_lag'
#  'autocorrelation_113_lag' 'autocorrelation_114_lag'
#  'autocorrelation_115_lag' 'autocorrelation_116_lag'
#  'autocorrelation_117_lag' 'autocorrelation_118_lag'
#  'autocorrelation_119_lag' 'autocorrelation_120_lag'
#  'autocorrelation_121_lag' 'autocorrelation_122_lag'
#  'autocorrelation_123_lag' 'autocorrelation_124_lag'
#  'autocorrelation_125_lag' 'autocorrelation_126_lag'
#  'autocorrelation_127_lag' 'autocorrelation_128_lag'
#  'autocorrelation_129_lag' 'autocorrelation_130_lag'
#  'autocorrelation_131_lag' 'autocorrelation_132_lag'
#  'autocorrelation_133_lag' 'autocorrelation_134_lag'
#  'autocorrelation_135_lag' 'autocorrelation_136_lag'
#  'autocorrelation_137_lag' 'autocorrelation_138_lag'
#  'autocorrelation_139_lag' 'autocorrelation_140_lag'
#  'autocorrelation_141_lag' 'autocorrelation_142_lag'
#  'autocorrelation_143_lag' 'autocorrelation_144_lag'
#  'autocorrelation_145_lag' 'autocorrelation_146_lag'
#  'autocorrelation_147_lag' 'autocorrelation_148_lag'
#  'autocorrelation_149_lag' 'autocorrelation_150_lag'
#  'autocorrelation_151_lag' 'autocorrelation_152_lag'
#  'autocorrelation_153_lag' 'autocorrelation_154_lag'
#  'autocorrelation_155_lag' 'autocorrelation_156_lag'
#  'autocorrelation_157_lag' 'autocorrelation_158_lag'
#  'autocorrelation_159_lag' 'autocorrelation_160_lag'
#  'autocorrelation_161_lag' 'autocorrelation_162_lag'
#  'autocorrelation_163_lag' 'autocorrelation_164_lag'
#  'autocorrelation_165_lag' 'autocorrelation_166_lag'
#  'autocorrelation_167_lag' 'autocorrelation_168_lag'
#  'autocorrelation_169_lag' 'autocorrelation_170_lag'
#  'autocorrelation_171_lag' 'autocorrelation_172_lag'
#  'autocorrelation_173_lag' 'autocorrelation_174_lag'
#  'autocorrelation_175_lag' 'autocorrelation_176_lag'
#  'autocorrelation_177_lag' 'autocorrelation_178_lag'
#  'autocorrelation_179_lag' 'autocorrelation_180_lag'
#  'autocorrelation_181_lag' 'autocorrelation_182_lag'
#  'autocorrelation_183_lag' 'autocorrelation_184_lag'
#  'autocorrelation_185_lag' 'autocorrelation_186_lag'
#  'autocorrelation_187_lag' 'autocorrelation_188_lag'
#  'autocorrelation_189_lag' 'autocorrelation_190_lag'
#  'autocorrelation_191_lag' 'autocorrelation_192_lag'
#  'autocorrelation_193_lag' 'autocorrelation_194_lag'
#  'autocorrelation_195_lag' 'autocorrelation_196_lag'
#  'autocorrelation_197_lag' 'autocorrelation_198_lag'
#  'autocorrelation_199_lag' 'autocorrelation_200_lag' 'max_autocorrelation']

# %% [markdown]
# The following cell drops the low-variance features. Only execute it when you are sure of the features you want to remove.

# %%
all_features_2 = all_features.drop(columns=low_variance_features, inplace=False, errors="ignore")
print(f"There are {all_features_2.shape[1]} features left.")
# Out:
# There are 50 features left.

# %% [markdown]
# #### Check outliers

# %% [markdown]
# <div class="alert alert-success" role="alert">
#     <p><b>Question</b></p>
#     <p> One feature has larger variations than the others: which one is it? (Name it <tt>feature_to_check</tt>.) Show the associated boxplot.</p>
# </div>

# %%
variances = all_features.var()
feature_to_check = variances.idxmax()
plt.figure(figsize=(8, 6))
plt.boxplot(all_features[feature_to_check])
plt.show()
print(f"The feature with the largest variation is: {feature_to_check}")
# Out:
# The feature with the largest variation is: kurtosis

# %% [markdown]
# <div class="alert alert-success" role="alert">
#     <p><b>Question</b></p>
#     <p> Check the outliers. Is there something we can do to remediate this issue?</p>
# </div>

# %%
import pandas as pd
import matplotlib.pyplot as plt

Q1 = all_features[feature_to_check].quantile(0.25)
Q3 = all_features[feature_to_check].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = all_features[(all_features[feature_to_check] < lower_bound) | (all_features[feature_to_check] > upper_bound)]

print("Outliers:")
print(outliers[feature_to_check])
# Out:
# Outliers:
# 22      49.993077
# 45      35.246070
# 67      28.786118
# 74      29.064857
# 99      50.772796
# 107     28.013657
# 137    136.054567
# 138     89.300176
# 152     30.130201
# 155     32.542478
# 177     36.236156
# Name: kurtosis, dtype: float64

# %% [markdown]
# ### Multicollinearity
#
# Multicollinearity degrades numerical stability and interpretability.
# Compute the correlation.
# Features with a correlation above a threshold are grouped together in a cluster.
# We then choose a single feature from each cluster.

# %%
correlation_threshold = 0.8

# %%
corr = pdist(all_features.to_numpy().T, metric="correlation")  # distance matrix
plt.imshow(squareform(corr))

# %%
fig, ax = fig_ax((20, 10))
corr_linkage = hierarchy.average(np.nan_to_num(corr))
dendro = hierarchy.dendrogram(
    corr_linkage, ax=ax, color_threshold=1 - correlation_threshold
)

# %%
# compute the clusters
cluster_ids = hierarchy.fcluster(
    corr_linkage, 1 - correlation_threshold, criterion="distance"
)

# print the largest clusters
largest_cluster_ind = np.bincount(cluster_ids).argmax()
print(
    f"The largest cluster is {all_features.columns[cluster_ids==largest_cluster_ind].tolist()}."
)

# for each cluster, only keep the first feature
keep_features = list()
for cluster in np.unique(cluster_ids):
    cluster_indexes = np.where(cluster_ids == cluster)[0]
    keep_features.append(all_features.columns[cluster_indexes[0]])
# Out:
# The largest cluster is ['fourier_360-380_Hz', 'fourier_380-400_Hz', 'fourier_400-420_Hz', 'fourier_420-440_Hz', 'fourier_440-460_Hz', 'fourier_460-480_Hz', 'fourier_480-500_Hz', 'fourier_500-520_Hz', 'fourier_520-540_Hz', 'fourier_540-560_Hz', 'fourier_560-580_Hz', 'fourier_580-600_Hz', 'fourier_600-620_Hz', 'fourier_620-640_Hz', 'fourier_640-660_Hz', 'fourier_660-680_Hz', 'fourier_680-700_Hz', 'fourier_700-720_Hz', 'fourier_720-740_Hz'].

# %%
# Reduce the number of features
all_features = all_features[keep_features]

# %% [markdown]
# <div class="alert alert-success" role="alert">
#     <p><b>Question</b></p>
#     <p> How many features do we have in the end?</p>
# </div>

# %%
all_features.shape
# Out:
# (204, 40)

# %% [markdown]
# ### PCA

# %%
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy='mean')
all_features_centered = all_features.to_numpy()
all_features_centered = imputer.fit_transform(all_features_centered)

all_features_centered -= all_features_centered.mean(axis=0)
all_features_centered /= all_features_centered.std(axis=0)

pca = PCA(n_components=2).fit(all_features_centered)

# %%
pca = PCA(n_components=2).fit(all_features)

# %%
# select the 5 most important features (with highest norm).
top_features_for_pca = np.linalg.norm(pca.components_, axis=0).argsort()[-5:]

for feature_ind in top_features_for_pca:
    msg = f"{all_features.columns[feature_ind]}: {(pca.components_.T[feature_ind]**2).sum():.3f}"
    print(msg)
# Out:
# fourier_360-380_Hz: 0.001
# fourier_740-760_Hz: 0.001
# fourier_0-20_Hz: 0.001
# kurtosis: 0.998
# lag_max_autocorrelation_Hz: 0.998

# %%
# plot the 2D projection of the top 5 features
fig, ax = fig_ax(figsize=(8, 8))
ax.axis("equal")
for feature_ind in top_features_for_pca:  # normaliser par la variance
    dx, dy = pca.components_.T[feature_ind]
    ax.plot([0, dx], [0, dy], label=all_features.columns[feature_ind])
ax.set_xlabel(f"PC1 ({pca.explained_variance_[0]:.1f}% of variance)")
ax.set_ylabel(f"PC1 ({pca.explained_variance_[1]:.1f}% of variance)")
_ = plt.legend()

# %% [markdown]
# <div class="alert alert-success" role="alert">
#     <p><b>Question</b></p>
#     <p> Normalize all features to unit variance and redo the PCA.</p>
# </div>

# %%
pca = PCA(n_components=2).fit(all_features_centered)

# plot the 2D projection of the top 5 features
fig, ax = fig_ax(figsize=(8, 8))
ax.axis("equal")
for feature_ind in top_features_for_pca:  # normaliser par la variance
    dx, dy = pca.components_.T[feature_ind]
    ax.plot([0, dx], [0, dy], label=all_features.columns[feature_ind])
ax.set_xlabel(f"PC1 ({pca.explained_variance_[0]:.1f}% of variance)")
ax.set_ylabel(f"PC1 ({pca.explained_variance_[1]:.1f}% of variance)")
_ = plt.legend()

# %% [markdown]
# ## Supervised selection

# %% [markdown]
# Three main classes of methods:
#
# - **Filter methods.** We test the adequacy of the feature with the annotations, thanks to several criterion/scores (e.g. correlation).
# - **Wrapper methods.** We test the features on a supervised classification task, by trying several combinations. The best features are kept.
# - **Embedded methods.** Mixed approaches where we jointly infer the relevance of the features and classify the data (decision tree, sparse methods...)

# %% [markdown]
# ### Filter methods
#
# If a feature is highly correlated with a label, it can help achieve good classification performance.
#
# For classification tasks, ANOVA.

# %%
labels = y_train
statistics, pvalues = f_oneway(
    all_features[labels == "Abnormal"], all_features[labels == "Normal"]
)

# %%
for ind in statistics.argsort()[::-1]:
    print(f"{all_features.columns[ind]}: {statistics[ind]:.3f}")
# Out:
# max: 16.456
# fourier_740-760_Hz: 14.957
# min: 13.055
# fourier_40-60_Hz: 12.309
# autocorrelation_49_lag: 11.991
# autocorrelation_14_lag: 11.314
# autocorrelation_22_lag: 7.894
# fourier_0-20_Hz: 6.644
# autocorrelation_136_lag: 4.152
# std: 2.934
# autocorrelation_57_lag: 2.772
# fourier_360-380_Hz: 2.462
# fourier_60-80_Hz: 2.115
# mean: 1.944
# fourier_20-40_Hz: 1.938
# autocorrelation_148_lag: 1.884
# fourier_240-260_Hz: 1.821
# fourier_80-100_Hz: 1.728
# 50%: 1.256
# autocorrelation_124_lag: 1.199
# lag_max_autocorrelation_Hz: 1.130
# fourier_120-140_Hz: 1.053
# autocorrelation_104_lag: 0.789
# autocorrelation_1_lag: 0.701
# autocorrelation_71_lag: 0.434
# autocorrelation_81_lag: 0.430
# autocorrelation_95_lag: 0.396
# autocorrelation_191_lag: 0.361
# autocorrelation_3_lag: 0.266
# max_autocorrelation: 0.213
# autocorrelation_62_lag: 0.169
# autocorrelation_177_lag: 0.102
# autocorrelation_30_lag: 0.045
# fourier_160-180_Hz: 0.041
# autocorrelation_169_lag: 0.039
# kurtosis: 0.029
# autocorrelation_157_lag: 0.014
# autocorrelation_116_lag: 0.011
# 25%: 0.005
# autocorrelation_89_lag: 0.000

# %% [markdown]
# ### Wrapper methods
#
# For a given learning algorithm, wrapper methods repeatedly select a subset of features and evaluate the selected features. Several procedures exist to select a subset but the most common are greedy and iterative; they either remove (backward selection) or add a feature (forward selection) sequentially.

# %%
# At each steps, SequentialFeatureSelector adds the best scoring feature to
# the set of selected features.
# For a given estimator, the score is computed with cross-validation.
knn = KNeighborsClassifier(n_neighbors=5)
sfs = SequentialFeatureSelector(
    knn, n_features_to_select=20, cv=5, scoring=make_scorer(accuracy_score)
)
sfs.fit(all_features, labels)

print("Selected features:")
print(all_features.columns[sfs.get_support()].tolist())
# Out:
# Selected features:
# ['autocorrelation_1_lag', 'autocorrelation_3_lag', 'autocorrelation_124_lag', 'autocorrelation_148_lag', 'autocorrelation_136_lag', '25%', '50%', 'autocorrelation_169_lag', 'autocorrelation_157_lag', 'autocorrelation_191_lag', 'autocorrelation_177_lag', 'mean', 'std', 'autocorrelation_22_lag', 'fourier_160-180_Hz', 'fourier_740-760_Hz', 'autocorrelation_95_lag', 'fourier_60-80_Hz', 'autocorrelation_49_lag', 'max_autocorrelation']

# %% [markdown]
# ### Embedded methods
#
# Such methods use the intrinsic structure of a learning algorithm to embed feature selection into the underlying model.

# %%
rf = RandomForestClassifier().fit(all_features, labels)

# %% [markdown]
# <div class="alert alert-success" role="alert">
#     <p><b>Question</b></p>
#     <p>Print features in descending order of importance, measured by the random forest feature importance (see the <tt>feature_importances_</tt> attribute).</p>
# </div>

# %%
columns = list(all_features.columns)
for i in np.argsort(rf.feature_importances_)[::-1]:
    print(columns[i])
# Out:
# fourier_740-760_Hz
# std
# 25%
# 50%
# max
# autocorrelation_14_lag
# autocorrelation_49_lag
# mean
# autocorrelation_148_lag
# fourier_60-80_Hz
# autocorrelation_22_lag
# max_autocorrelation
# lag_max_autocorrelation_Hz
# autocorrelation_169_lag
# autocorrelation_136_lag
# min
# fourier_80-100_Hz
# fourier_40-60_Hz
# autocorrelation_157_lag
# fourier_360-380_Hz
# autocorrelation_30_lag
# fourier_120-140_Hz
# autocorrelation_3_lag
# kurtosis
# autocorrelation_116_lag
# fourier_240-260_Hz
# autocorrelation_57_lag
# autocorrelation_104_lag
# fourier_160-180_Hz
# fourier_0-20_Hz
# fourier_20-40_Hz
# autocorrelation_177_lag
# autocorrelation_191_lag
# autocorrelation_81_lag
# autocorrelation_95_lag
# autocorrelation_124_lag
# autocorrelation_62_lag
# autocorrelation_71_lag
# autocorrelation_89_lag
# autocorrelation_1_lag
